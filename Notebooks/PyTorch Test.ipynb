# %%
import torch

# %%
t = torch.tensor([[1,2,3], [1,2,2]])

# %%
if torch.cuda.is_available():
    t = t.cuda()
t
# Out:
# tensor([[1, 2, 3],
#         [1, 2, 2]], device='cuda:0')

# %%
t.shape
# Out:
# torch.Size([2, 3])

# %%
len(t.shape)
# Out:
# 2

# %%
t.reshape(1,6)
# Out:
# tensor([[1, 2, 3, 1, 2, 2]], device='cuda:0')

# %%
t.reshape(3,2)
# Out:
# tensor([[1, 2],
#         [3, 1],
#         [2, 2]], device='cuda:0')
